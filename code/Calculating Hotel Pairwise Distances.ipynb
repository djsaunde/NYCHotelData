# %% [markdown]
# For each hotel listed in the "Manhattan_selected_to_SLR" workbook, we'll calculate distances from it to all other hotels, and store the result in a new workbook entitled "Hotel Pairwise Distances".
#
# ## Imports...

# %%
# data manipulation package (provides "dataframe" data structure)
import pandas as pd

# linear algebra / matrix package (provides "ndarray" data structure)
import numpy as np

# vincenty distance formula
from geopy.distance import vincenty

# %% [markdown]
# ## Getting the Data
#
# First, let's read in the "Names, Addresses, ID, and Coordinates" workbook I put together earlier.

# %%
# read in the data
hotel_data = pd.read_excel('../data/Hotel Names, Addresses, ID, and Coordinates.xlsx')

# take a look at the result
hotel_data
# Out:
#      Share ID                                               Name  \
# 0      107972                               1 Hotel Central Park
# 1     5639782                                          11 Howard
# 2      120886                                 Ace Hotel New York
# 3     2252008                                   Ameritania Hotel
# 4      105038                                  Andaz Wall Street
# 5      119324                              Archer Hotel New York
# 6       91126                                 Arlo Hudson Square
# 7      112473     Ascend Collection Distrikt Hotel New York City
# 8     7221375                 Autograph Collection Carlton Hotel
# 9     8341862   Autograph Collection The Lexington New York City
# 10     113189                   Best Western Bowery Hanbee Hotel
# 11    1318511                                  Bryant Park Hotel
# 12     118540            Cambria hotel & suites New York Chelsea
# 13     102762       Candlewood Suites New York City Times Square
# 14     115325                     citizenM New York Times Square
# 15    6236370                                    Conrad New York
# 16    4491967            Courtyard New York Manhattan 5th Avenue
# 17      91329          Courtyard New York Manhattan Central Park
# 18     103783               Courtyard New York Manhattan Chelsea
# 19     105140         Courtyard New York Manhattan Herald Square
# 20    2730750          Courtyard New York Manhattan Midtown East
# 21      92349                  Courtyard New York Manhattan SoHo
# 22     211466    Courtyard New York Manhattan Times Square South
# 23      89044     Courtyard New York Manhattan Times Square West
# 24    1536334                Crowne Plaza Times Square Manhattan
# 25      93324  Curio Collection The Renwick Hotel New York City
# 26    8763088        DoubleTree Hotel Metropolitan New York City
# 27      86091                   Doubletree New York City Chelsea
# 28      99666        Doubletree New York City Financial District
# 29      83645             Doubletree New York Times Square South
# ..        ...                                                ...
# 148   3744548                                     The London NYC
# 149     84151                                   The Ludlow Hotel
# 150   9412233                 The Manhattan @ Times Square Hotel
# 151   5551403                              The Marcel @ Gramercy
# 152     89569                            The Marmara Park Avenue
# 153    114178                                    The NoMad Hotel
# 154    571214                             The Peninsula New York
# 155   5026568                 The Plaza A Fairmont Managed Hotel
# 156   5284407                               The Redbury New York
# 157   2740016                                 The Roger Williams
# 158   3082648                                The Roosevelt Hotel
# 159   8006641                             The Roxy Hotel Tribeca
# 160     96983                          The Standard East Village
# 161     98056                             The Standard High Line
# 162    105980                  Thompson Hotels The Beekman Hotel
# 163    123555               Trump Hotel Collection SoHo New York
# 164    112674  Tryp by Wyndham New York City Times Square South
# 165    103095                                   Viceroy New York
# 166   3190052                                   W Hotel New York
# 167     84511                          W Hotel New York Downtown
# 168   9498391                      W Hotel New York Times Square
# 169  10167518                               W Hotel Union Square
# 170   6493834                           Waldorf Astoria New York
# 171     89567                     Walker Hotel Greenwich Village
# 172   9266902                             Warwick New York Hotel
# 173   2910603                     Westin New York @ Times Square
# 174   8456912                      Westin New York Grand Central
# 175     94971           Wyndham Garden Hotel Chinatown New York
# 176   1459363                           Wyndham New Yorker Hotel
# 177    118337                      Yotel New York @ Times Square
#
#                          Address                              Coordinates
# 0    1414 Avenue Of The Americas                (40.7647485, -73.9764725)
# 1                   11 Howard St         (40.7191766, -73.99992759999999)
# 2                   20 W 29th St                (40.7457432, -73.9882603)
# 3                  230 W 54th St                (40.7640045, -73.9829075)
# 4                     75 Wall St                (40.7051404, -74.0079954)
# 5                   45 W 38th St                 (40.752027, -73.9847224)
# 6                  231 Hudson St         (40.7244391, -74.00823749999999)
# 7                  342 W 40th St                (40.7566314, -73.9928546)
# 8                 88 Madison Ave                (40.7444291, -73.9857968)
# 9              511 Lexington Ave                (40.7548069, -73.9731814)
# 10                  231 Grand St                (40.7184002, -73.9952811)
# 11                  40 W 40th St  (40.75281280000001, -73.98376499999999)
# 12                 123 W 28th St                (40.7467552, -73.9915459)
# 13                 339 W 39th St                (40.7563122, -73.9929689)
# 14                 218 W 50th St                  (40.761561, -73.984968)
# 15             102 North End Ave                  (40.714989, -74.015236)
# 16                   3 E 40th St          (40.752057, -73.98109459999999)
# 17                 1717 Broadway                 (40.7643734, -73.982743)
# 18                 135 W 30th St                (40.7482231, -73.9911923)
# 19        71 W 35th St @ 6th Ave                (40.7504619, -73.9872841)
# 20                   866 3rd Ave                (40.7575426, -73.9700204)
# 21                 181 Varick St                (40.7275481, -74.0058074)
# 22                 114 W 40th St                 (40.753944, -73.9859878)
# 23                 307 W 37th St                (40.7544922, -73.9925544)
# 24                 1605 Broadway                (40.7603998, -73.9848876)
# 25                 118 E 40th St                (40.7501895, -73.9775843)
# 26             569 Lexington Ave                (40.7567148, -73.9714247)
# 27                 128 W 29th St         (40.7469627, -73.99142719999999)
# 28                    8 Stone St          (40.703861, -74.01233069999999)
# 29                 341 W 36th St         (40.7543497, -73.99411900000001)
# ..                           ...                                      ...
# 148                151 W 54th St                (40.7635061, -73.9806361)
# 149                180 Ludlow St         (40.7218313, -73.98722149999999)
# 150                  790 7th Ave                 (40.761985, -73.9829247)
# 151                201 E 24th St                (40.7394842, -73.9822559)
# 152                114 E 32nd St                (40.7453037, -73.9816202)
# 153                1170 Broadway         (40.7449457, -73.98845589999999)
# 154                  700 5th Ave         (40.7616194, -73.97541439999999)
# 155                  768 5th Ave         (40.7646095, -73.97435469999999)
# 156                 29 E 29th St                (40.7447125, -73.9844689)
# 157              131 Madison Ave                (40.7456133, -73.9841399)
# 158                 45 E 45th St         (40.7547501, -73.97747869999999)
# 159        2 Ave Of The Americas  (40.71938129999999, -74.00478100000001)
# 160                 25 Cooper Sq                (40.7279316, -73.9907857)
# 161            848 Washington St                 (40.740854, -74.0079523)
# 162                 5 Beekman St                (40.7111944, -74.0069018)
# 163                246 Spring St                    (32.787083, -79.9553)
# 164               345 W 35th St                    (40.75377, -73.994541)
# 165                120 W 57th St                (40.7645582, -73.9784803)
# 166            541 Lexington Ave                (40.7561148, -73.9722118)
# 167                  8 Albany St                (40.7091948, -74.0135809)
# 168                1567 Broadway         (40.7593257, -73.98559949999999)
# 169               201 Park Ave S                (44.9776501, -93.2586615)
# 170                 301 Park Ave         (40.7565712, -73.97364209999999)
# 171                 52 W 13th St         (40.7361469, -73.99666169999999)
# 172                 65 W 54th St                (40.7624022, -73.9782725)
# 173                270 W 43rd St                 (40.757444, -73.9891926)
# 174                212 E 42nd St                (40.7502017, -73.9740114)
# 175                93 Bowery St                 (40.7170107, -73.9951885)
# 176                  481 8th Ave                (40.7527038, -73.9934785)
# 177                 570 10th Ave                (40.7591568, -73.9954561)
#
# [178 rows x 4 columns]

# %% [markdown]
# ## Calculate Pairwise Distances
#
# For each hotel, calculate the distance from it to all other hotels. The distances will be stored in a 178 x 178 matrix, output in an Excel workbook.

# %%
distances = np.zeros((178, 178), dtype=np.float32)

for i, hotel1 in hotel_data.iterrows():
    for k, hotel2 in hotel_data.iterrows():
        distances[i, k] = vincenty(hotel1['Coordinates'], hotel2['Coordinates']).miles

# caste the numpy matrix of distances into a pandas dataframe (indexing / columns with hotel addresses)
distances = pd.DataFrame(distances, index=hotel_data['Name'], columns=hotel_data['Name'])

# %%
# write the distances dataframe to an Excel workbook
writer = pd.ExcelWriter('../data/Hotel Pairwise Distances.xlsx')
distances.to_excel(writer, 'Pairwise Distances')
writer.close()
